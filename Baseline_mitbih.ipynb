# %%
import pandas as pd
import numpy as np

import tensorflow
from tensorflow.keras import optimizers, losses, activations, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate
from tensorflow.keras.models import load_model

from sklearn.metrics import f1_score, accuracy_score

# %% [markdown]
# ### MITBIH baseline
# #### Code mostly from https://github.com/CVxTz/ECG_Heartbeat_Classification/blob/master/code/baseline_mitbih.py

# %%
df_train = pd.read_csv("data/mitbih_train.csv", header=None)
df_train = df_train.sample(frac=1)
df_test = pd.read_csv("data/mitbih_test.csv", header=None)

Y = np.array(df_train[187].values).astype(np.int8)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

# %% [markdown]
# ### Load model

# %%
model = load_model("baseline_cnn_mitbih.h5")

# %% [markdown]
# ### Or ALTERNATIVELY train it

# %%
def get_model():
    nclass = 5
    inp = Input(shape=(187, 1))
    img_1 = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(inp)
    img_1 = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid", name="final_conv")(img_1)
    img_1 = GlobalMaxPool1D()(img_1)
    img_1 = Dropout(rate=0.2)(img_1)

    dense_1 = Dense(64, activation=activations.relu, name="dense_1")(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])
    model.summary()
    return model

# %%
model = get_model()
file_path = "baseline_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 187, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 183, 16)           96
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 179, 16)           1296
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 89, 16)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 89, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 87, 32)            1568
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 85, 32)            3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 42, 32)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 38, 32)            3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 19, 32)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 19, 32)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 17, 256)           24832
# _________________________________________________________________
# final_conv (Conv1D)          (None, 15, 256)           196864
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_mitbih (Dense)       (None, 5)                 325
# =================================================================
# Total params: 254,901
# Trainable params: 254,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 78798 samples, validate on 8756 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.94484, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 81s - loss: 0.3686 - acc: 0.8915 - val_loss: 0.2016 - val_acc: 0.9448
# Epoch 2/1000
#
# Epoch 00002: val_acc improved from 0.94484 to 0.95900, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 77s - loss: 0.2046 - acc: 0.9441 - val_loss: 0.1460 - val_acc: 0.9590
# Epoch 3/1000
#
# Epoch 00003: val_acc improved from 0.95900 to 0.97008, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 80s - loss: 0.1539 - acc: 0.9583 - val_loss: 0.1137 - val_acc: 0.9701
# Epoch 4/1000
#
# Epoch 00004: val_acc improved from 0.97008 to 0.97190, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 77s - loss: 0.1323 - acc: 0.9647 - val_loss: 0.1033 - val_acc: 0.9719
# Epoch 5/1000
#
# Epoch 00005: val_acc did not improve from 0.97190
# 78798/78798 - 76s - loss: 0.1215 - acc: 0.9673 - val_loss: 0.1178 - val_acc: 0.9693
# Epoch 6/1000
#
# Epoch 00006: val_acc improved from 0.97190 to 0.97567, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 73s - loss: 0.1118 - acc: 0.9694 - val_loss: 0.0875 - val_acc: 0.9757
# Epoch 7/1000
#
# Epoch 00007: val_acc improved from 0.97567 to 0.97773, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 78s - loss: 0.1031 - acc: 0.9718 - val_loss: 0.0807 - val_acc: 0.9777
# Epoch 8/1000
#
# Epoch 00008: val_acc improved from 0.97773 to 0.97967, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 77s - loss: 0.0974 - acc: 0.9732 - val_loss: 0.0759 - val_acc: 0.9797
# Epoch 9/1000
#
# Epoch 00009: val_acc improved from 0.97967 to 0.98093, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 82s - loss: 0.0924 - acc: 0.9745 - val_loss: 0.0693 - val_acc: 0.9809
# Epoch 10/1000
#
# Epoch 00010: val_acc improved from 0.98093 to 0.98127, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 82s - loss: 0.0860 - acc: 0.9759 - val_loss: 0.0710 - val_acc: 0.9813
# Epoch 11/1000
#
# Epoch 00011: val_acc did not improve from 0.98127
# 78798/78798 - 81s - loss: 0.0828 - acc: 0.9766 - val_loss: 0.0863 - val_acc: 0.9741
# Epoch 12/1000
#
# Epoch 00012: val_acc improved from 0.98127 to 0.98470, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 82s - loss: 0.0761 - acc: 0.9778 - val_loss: 0.0568 - val_acc: 0.9847
# Epoch 13/1000
#
# Epoch 00013: val_acc did not improve from 0.98470
# 78798/78798 - 82s - loss: 0.0740 - acc: 0.9789 - val_loss: 0.0572 - val_acc: 0.9833
# Epoch 14/1000
#
# Epoch 00014: val_acc did not improve from 0.98470
# 78798/78798 - 91s - loss: 0.0722 - acc: 0.9797 - val_loss: 0.0581 - val_acc: 0.9822
# Epoch 15/1000
#
# Epoch 00015: val_acc did not improve from 0.98470
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 78798/78798 - 76s - loss: 0.0696 - acc: 0.9800 - val_loss: 0.0584 - val_acc: 0.9839
# Epoch 16/1000
#
# Epoch 00016: val_acc improved from 0.98470 to 0.98755, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 75s - loss: 0.0519 - acc: 0.9849 - val_loss: 0.0444 - val_acc: 0.9876
# Epoch 17/1000
#
# Epoch 00017: val_acc improved from 0.98755 to 0.98778, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 74s - loss: 0.0467 - acc: 0.9861 - val_loss: 0.0436 - val_acc: 0.9878
# Epoch 18/1000
#
# Epoch 00018: val_acc improved from 0.98778 to 0.98847, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 73s - loss: 0.0459 - acc: 0.9863 - val_loss: 0.0424 - val_acc: 0.9885
# Epoch 19/1000
#
# Epoch 00019: val_acc improved from 0.98847 to 0.98869, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 79s - loss: 0.0450 - acc: 0.9864 - val_loss: 0.0422 - val_acc: 0.9887
# Epoch 20/1000
#
# Epoch 00020: val_acc improved from 0.98869 to 0.98915, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 79s - loss: 0.0425 - acc: 0.9869 - val_loss: 0.0416 - val_acc: 0.9892
# Epoch 21/1000
#
# Epoch 00021: val_acc did not improve from 0.98915
# 78798/78798 - 85s - loss: 0.0416 - acc: 0.9873 - val_loss: 0.0401 - val_acc: 0.9888
# Epoch 22/1000
#
# Epoch 00022: val_acc did not improve from 0.98915
# 78798/78798 - 82s - loss: 0.0401 - acc: 0.9877 - val_loss: 0.0413 - val_acc: 0.9890
# Epoch 23/1000
#
# Epoch 00023: val_acc did not improve from 0.98915
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 78798/78798 - 83s - loss: 0.0391 - acc: 0.9880 - val_loss: 0.0408 - val_acc: 0.9888
# Epoch 24/1000
#
# Epoch 00024: val_acc did not improve from 0.98915
# 78798/78798 - 81s - loss: 0.0366 - acc: 0.9887 - val_loss: 0.0406 - val_acc: 0.9892
# Epoch 25/1000
#
# Epoch 00025: val_acc improved from 0.98915 to 0.98938, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 93s - loss: 0.0376 - acc: 0.9883 - val_loss: 0.0402 - val_acc: 0.9894
# Epoch 26/1000
#
# Epoch 00026: val_acc improved from 0.98938 to 0.98961, saving model to baseline_cnn_mitbih.h5
# 78798/78798 - 126s - loss: 0.0364 - acc: 0.9888 - val_loss: 0.0401 - val_acc: 0.9896
# Epoch 27/1000
#
# Epoch 00027: val_acc did not improve from 0.98961
# 78798/78798 - 130s - loss: 0.0366 - acc: 0.9888 - val_loss: 0.0400 - val_acc: 0.9895
# Epoch 28/1000
#
# Epoch 00028: val_acc did not improve from 0.98961
# 78798/78798 - 129s - loss: 0.0366 - acc: 0.9883 - val_loss: 0.0399 - val_acc: 0.9890
# Epoch 29/1000
#
# Epoch 00029: val_acc did not improve from 0.98961
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 78798/78798 - 129s - loss: 0.0363 - acc: 0.9885 - val_loss: 0.0398 - val_acc: 0.9892
# Epoch 30/1000
#
# Epoch 00030: val_acc did not improve from 0.98961
# 78798/78798 - 129s - loss: 0.0357 - acc: 0.9889 - val_loss: 0.0398 - val_acc: 0.9892
# Epoch 31/1000
#
# Epoch 00031: val_acc did not improve from 0.98961
# 78798/78798 - 134s - loss: 0.0366 - acc: 0.9888 - val_loss: 0.0398 - val_acc: 0.9892
# Epoch 00031: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(X_test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(Y_test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test)

print("Test accuracy score : %s "% acc)

print(tensorflow.math.confusion_matrix(
    Y_test, pred_test, num_classes=5))
# Out:
# Test f1 score : 0.9178519794244808
# Test accuracy score : 0.9857482185273159
# tf.Tensor(
# [[18049    41    17     5     6]
#  [   99   442    14     0     1]
#  [   46     5  1381    12     4]
#  [   28     0    15   119     0]
#  [   18     0     1     0  1589]], shape=(5, 5), dtype=int32)
